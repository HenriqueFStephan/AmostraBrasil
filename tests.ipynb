# %%
import sys
from pathlib import Path
# Add py/ so amostra_brasil is importable (notebook run from project root)
sys.path.insert(0, str(Path.cwd() / "py"))

# %%
# Import from submodule so it works even if kernel cached an old package __init__
from amostra_brasil.municipios import load_municipios, resolve_municipio

load_municipios()
print(resolve_municipio(municipio="Pindoba"))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from amostra_brasil import load_municipios, resolve_municipio
#       3 load_municipios()
#       4 print(resolve_municipio(municipio="Pindoba"))
#
# ImportError: cannot import name 'resolve_municipio' from 'amostra_brasil' (c:\Users\henri\OneDrive\Área de Trabalho\VSC\AmostraBrasil\AmostraBrasil\py\amostra_brasil\__init__.py)
